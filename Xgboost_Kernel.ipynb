# %%
import csv
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split, cross_val_score

# %%
df_all=pd.read_csv('data_original.csv')
df_teid=pd.read_csv('sample_submission.csv')

# %%
#split data into training and testing
test_id=df_teid['shot_id'].tolist()

# %%
df_all['shot_made_flag'].value_counts()
# Out:
# 0.0    14232
# 1.0    11465
# Name: shot_made_flag, dtype: int64

# %%
df_all['combined_shot_type'].value_counts()
# Out:
# Jump Shot    23485
# Layup         5448
# Dunk          1286
# Tip Shot       184
# Hook Shot      153
# Bank Shot      141
# Name: combined_shot_type, dtype: int64

# %%
df_all['period'].value_counts()
# Out:
# 3    8296
# 1    8048
# 4    7260
# 2    6718
# 5     330
# 6      38
# 7       7
# Name: period, dtype: int64

# %%
df_all['shot_zone_area'].value_counts()
# Out:
# Center(C)                13455
# Right Side Center(RC)     4776
# Right Side(R)             4588
# Left Side Center(LC)      4044
# Left Side(L)              3751
# Back Court(BC)              83
# Name: shot_zone_area, dtype: int64

# %%
df_all['shot_zone_basic'].value_counts()
# Out:
# Mid-Range                12625
# Restricted Area           7136
# Above the Break 3         5620
# In The Paint (Non-RA)     4578
# Right Corner 3             387
# Left Corner 3              280
# Backcourt                   71
# Name: shot_zone_basic, dtype: int64

# %%
df_all['shot_type'].value_counts()
# Out:
# 2PT Field Goal    24271
# 3PT Field Goal     6426
# Name: shot_type, dtype: int64

# %%
df_all['opponent'].value_counts()
# Out:
# SAS    1978
# PHX    1781
# HOU    1666
# SAC    1643
# DEN    1642
# POR    1539
# UTA    1490
# MIN    1474
# GSW    1356
# LAC    1285
# DAL    1199
# MEM    1030
# BOS     946
# SEA     828
# IND     761
# PHI     720
# ORL     719
# DET     715
# OKC     677
# TOR     664
# NYK     657
# MIA     627
# CHA     620
# CLE     619
# CHI     610
# WAS     600
# MIL     586
# NOH     581
# NJN     520
# ATL     519
# NOP     344
# VAN     246
# BKN      55
# Name: opponent, dtype: int64

# %%
#string format into datetime
df_all['game_date'] = pd.to_datetime(df_all['game_date'])

# %%
#if it is a back to back game 
#(df_all['game_date'][100]-df_all['game_date'][1]).days #int
def btb(lst): #0,1
    btb_lst=[0]
    flag=0
    for i in range(1,len(lst)):
        if (lst[i]-lst[i-1]).days==1:
            btb_lst.append(1)
            flag=1
        elif (lst[i]-lst[i-1]).days==0:
            btb_lst.append(flag)
        else:
            flag=0
            btb_lst.append(flag)
    return btb_lst

df_all['btb']=btb(df_all['game_date'])

# %%
#home court game or not
def homecourt(row):
    if '@' in row:
        return 0
    elif 'vs' in row:
        return 1
    else:
        return 'error'
    


homecourt_label=df_all['matchup'].apply(homecourt)
df_all['homecourt']=homecourt_label

# %%
#game month
#w['female'] = w['female'].map({'female': 1, 'male': 0})
def gamemonth(lst):
    dict_month={'1': 'Jan', '2': 'Feb', '3': 'Mar',
                '4': 'Apr', '5': 'May', '6': 'Jun',
                '7': 'Jul', '8': 'Aug', '9': 'Sep',
                '10': 'Oct', '11': 'Nov', '12': 'Dec'}
    
    splitseries=lst.apply(lambda row :str(row.month))
    
    newseries=splitseries.map(dict_month)
    
    return newseries
    
gamemonth(df_all['game_date']).isnull().values.any() #false
df_all['gamemonth']=gamemonth(df_all['game_date'])

# %%
#if last shot was made
def lastshot(lst):
    last=[0]
    for i in range(1,len(lst)):
        
        if lst[i-1]==0:
            flag=0
            last.append(0)
        elif lst[i-1]==1:
            flag=1
            last.append(1)
        else:
            last.append('unknown') #due to the random test data
    return last

df_all['last_shot_flag']=lastshot(df_all['shot_made_flag'])

# %%
#add column secondsToPeriodEnd
df_all['secondsToPeriodEnd'] = 60*df_all['minutes_remaining']+df_all['seconds_remaining']

# %%
#add column secondsFromPeriodEnd
df_all['secondsFromGameStart'] = df_all['period'].astype(int)*12*60 - df_all['secondsToPeriodEnd']

# %%
criterion = df_all['shot_id'].map(lambda x: x not in test_id)
criterion1 = df_all['shot_id'].map(lambda x: x in test_id)
df_all_tr=df_all[criterion]
df_all_te=df_all[criterion1]

# %%
ctg_feature=['combined_shot_type', 
             'shot_id','shot_type', 
             'action_type',
             'shot_zone_area', 'shot_zone_basic', 'playoffs', 'period','opponent','season',
             'homecourt',
             'btb',
             'gamemonth',
            'last_shot_flag'
             ]
num_feature=['loc_x', 'loc_y', 'shot_distance','shot_id','seconds_remaining',
             'secondsToPeriodEnd','secondsFromGameStart']

# %%
df_ctg = df_all.loc[:, lambda df: ctg_feature]
encoded_ctg=pd.get_dummies(df_ctg).astype(np.int16)

# %%
criterion01 = encoded_ctg['shot_id'].map(lambda x: x not in test_id)
criterion11 = encoded_ctg['shot_id'].map(lambda x: x in test_id)


df_tr_ctg=encoded_ctg[criterion01]
df_te_ctg=encoded_ctg[criterion11]

# %%
df_tr_num = df_all_tr.loc[:, lambda df: num_feature]
df_te_num = df_all_te.loc[:, lambda df: num_feature]
flag = df_all_tr['shot_made_flag']

# %%
train=pd.merge(df_tr_ctg, df_tr_num,on='shot_id')

test=pd.merge(df_te_ctg, df_te_num,on='shot_id')

# %%
train.shape
# Out:
# (25697, 154)

# %%
#how new features look like
df_all.loc[:, lambda df: ['homecourt','btb','gamemonth','last_shot_flag']]
# Out:
#        homecourt  btb gamemonth last_shot_flag
# 0              0    0       Oct              0
# 1              0    0       Oct        unknown
# 2              0    0       Oct              0
# 3              0    0       Oct              1
# 4              0    0       Oct              0
# 5              0    0       Oct              1
# 6              0    0       Oct              0
# 7              0    0       Oct              1
# 8              0    0       Oct        unknown
# 9              0    0       Oct              1
# 10             0    0       Oct              0
# 11             1    1       Nov              0
# 12             1    1       Nov              1
# 13             1    1       Nov              1
# 14             1    1       Nov              0
# 15             1    1       Nov              0
# 16             1    1       Nov              0
# 17             1    1       Nov        unknown
# 18             1    1       Nov              1
# 19             1    1       Nov              0
# 20             1    1       Nov        unknown
# 21             1    1       Nov              0
# 22             1    1       Nov              0
# 23             1    1       Nov              1
# 24             1    1       Nov              1
# 25             1    1       Nov              1
# 26             1    1       Nov              0
# 27             1    1       Nov              0
# 28             1    1       Nov              0
# 29             1    1       Nov              0
# ...          ...  ...       ...            ...
# 30667          0    0       Jun              0
# 30668          0    0       Jun              0
# 30669          0    0       Jun        unknown
# 30670          1    0       Jun              0
# 30671          1    0       Jun              0
# 30672          1    0       Jun              0
# 30673          1    0       Jun              1
# 30674          1    0       Jun              0
# 30675          1    0       Jun              1
# 30676          1    0       Jun              0
# 30677          1    0       Jun              1
# 30678          1    0       Jun              0
# 30679          1    0       Jun              0
# 30680          1    0       Jun              0
# 30681          1    0       Jun        unknown
# 30682          1    0       Jun              1
# 30683          1    0       Jun        unknown
# 30684          1    0       Jun              0
# 30685          1    0       Jun              0
# 30686          1    0       Jun              0
# 30687          1    0       Jun        unknown
# 30688          1    0       Jun              0
# 30689          1    0       Jun              1
# 30690          1    0       Jun              0
# 30691          1    0       Jun              0
# 30692          1    0       Jun              0
# 30693          1    0       Jun              0
# 30694          1    0       Jun        unknown
# 30695          1    0       Jun              1
# 30696          1    0       Jun              0
#
# [30697 rows x 4 columns]

# %%
X_dtrain, X_deval, y_dtrain, y_deval = train_test_split(train, flag, random_state=2046, test_size=0.15)
prior = 0.4
dtrain = xgb.DMatrix(X_dtrain, y_dtrain)
deval = xgb.DMatrix(X_deval, y_deval)
watchlist = [(deval, 'eval')]
params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'colsample_bytree': 0.8,
    'eta': 0.1,
    'max_depth': 3,
    'seed': 2017,
    'silent': 1,
    'gamma':0.005,
    'subsample':0.8,
     'base_score': prior,
    'eval_metric': 'logloss'
}

clf = xgb.train(params, dtrain, 200, watchlist, early_stopping_rounds=50)
# Out:
# [0]	eval-logloss:0.674965
# Will train until eval-logloss hasn't improved in 50 rounds.
# [1]	eval-logloss:0.664048
# [2]	eval-logloss:0.657258
# [3]	eval-logloss:0.650059
# [4]	eval-logloss:0.643236
# [5]	eval-logloss:0.639566
# [6]	eval-logloss:0.634409
# [7]	eval-logloss:0.630276
# [8]	eval-logloss:0.627382
# [9]	eval-logloss:0.624279
# [10]	eval-logloss:0.621496
# [11]	eval-logloss:0.619179
# [12]	eval-logloss:0.618018
# [13]	eval-logloss:0.616575
# [14]	eval-logloss:0.615107
# [15]	eval-logloss:0.61381
# [16]	eval-logloss:0.612625
# [17]	eval-logloss:0.611673
# [18]	eval-logloss:0.610787
# [19]	eval-logloss:0.610081
# [20]	eval-logloss:0.609325
# [21]	eval-logloss:0.608787
# [22]	eval-logloss:0.60846
# [23]	eval-logloss:0.608008
# [24]	eval-logloss:0.607603
# [25]	eval-logloss:0.60732
# [26]	eval-logloss:0.606964
# [27]	eval-logloss:0.606663
# [28]	eval-logloss:0.606476
# [29]	eval-logloss:0.606028
# [30]	eval-logloss:0.605751
# [31]	eval-logloss:0.60572
# [32]	eval-logloss:0.605538
# [33]	eval-logloss:0.605303
# [34]	eval-logloss:0.605225
# [35]	eval-logloss:0.60522
# [36]	eval-logloss:0.605045
# [37]	eval-logloss:0.604877
# [38]	eval-logloss:0.604657
# [39]	eval-logloss:0.604576
# [40]	eval-logloss:0.60452
# [41]	eval-logloss:0.604478
# [42]	eval-logloss:0.604493
# [43]	eval-logloss:0.604364
# [44]	eval-logloss:0.604229
# [45]	eval-logloss:0.604146
# [46]	eval-logloss:0.604026
# [47]	eval-logloss:0.603991
# [48]	eval-logloss:0.603758
# [49]	eval-logloss:0.603678
# [50]	eval-logloss:0.603751
# [51]	eval-logloss:0.603704
# [52]	eval-logloss:0.603691
# [53]	eval-logloss:0.603547
# [54]	eval-logloss:0.603353
# [55]	eval-logloss:0.603301
# [56]	eval-logloss:0.603336
# [57]	eval-logloss:0.603245
# [58]	eval-logloss:0.603139
# [59]	eval-logloss:0.603081
# [60]	eval-logloss:0.602988
# [61]	eval-logloss:0.602865
# [62]	eval-logloss:0.602701
# [63]	eval-logloss:0.602293
# [64]	eval-logloss:0.602203
# [65]	eval-logloss:0.60215
# [66]	eval-logloss:0.602192
# [67]	eval-logloss:0.602137
# [68]	eval-logloss:0.602057
# [69]	eval-logloss:0.6021
# [70]	eval-logloss:0.602083
# [71]	eval-logloss:0.602061
# [72]	eval-logloss:0.602008
# [73]	eval-logloss:0.602018
# [74]	eval-logloss:0.601944
# [75]	eval-logloss:0.601839
# [76]	eval-logloss:0.601892
# [77]	eval-logloss:0.601838
# [78]	eval-logloss:0.601832
# [79]	eval-logloss:0.601964
# [80]	eval-logloss:0.601843
# [81]	eval-logloss:0.601962
# [82]	eval-logloss:0.601935
# [83]	eval-logloss:0.60188
# [84]	eval-logloss:0.601743
# [85]	eval-logloss:0.601639
# [86]	eval-logloss:0.601639
# [87]	eval-logloss:0.60163
# [88]	eval-logloss:0.601477
# [89]	eval-logloss:0.601571
# [90]	eval-logloss:0.601438
# [91]	eval-logloss:0.601495
# [92]	eval-logloss:0.601551
# [93]	eval-logloss:0.60146
# [94]	eval-logloss:0.60142
# [95]	eval-logloss:0.601483
# [96]	eval-logloss:0.60153
# [97]	eval-logloss:0.601467
# [98]	eval-logloss:0.601563
# [99]	eval-logloss:0.601448
# [100]	eval-logloss:0.601474
# [101]	eval-logloss:0.601546
# [102]	eval-logloss:0.601497
# [103]	eval-logloss:0.60161
# [104]	eval-logloss:0.601581
# [105]	eval-logloss:0.601645
# [106]	eval-logloss:0.601687
# [107]	eval-logloss:0.601743
# [108]	eval-logloss:0.601826
# [109]	eval-logloss:0.601795
# [110]	eval-logloss:0.60163
# [111]	eval-logloss:0.601626
# [112]	eval-logloss:0.601339
# [113]	eval-logloss:0.601381
# [114]	eval-logloss:0.601285
# [115]	eval-logloss:0.601264
# [116]	eval-logloss:0.601234
# [117]	eval-logloss:0.601156
# [118]	eval-logloss:0.601138
# [119]	eval-logloss:0.601095
# [120]	eval-logloss:0.601162
# [121]	eval-logloss:0.601132
# [122]	eval-logloss:0.601169
# [123]	eval-logloss:0.600983
# [124]	eval-logloss:0.600905
# [125]	eval-logloss:0.600875
# [126]	eval-logloss:0.600918
# [127]	eval-logloss:0.600932
# [128]	eval-logloss:0.600941
# [129]	eval-logloss:0.600824
# [130]	eval-logloss:0.600828
# [131]	eval-logloss:0.600805
# [132]	eval-logloss:0.600623
# [133]	eval-logloss:0.600629
# [134]	eval-logloss:0.600645
# [135]	eval-logloss:0.600742
# [136]	eval-logloss:0.600701
# [137]	eval-logloss:0.600762
# [138]	eval-logloss:0.600729
# [139]	eval-logloss:0.600692
# [140]	eval-logloss:0.600616
# [141]	eval-logloss:0.600613
# [142]	eval-logloss:0.600546
# [143]	eval-logloss:0.600614
# [144]	eval-logloss:0.600621
# [145]	eval-logloss:0.600749
# [146]	eval-logloss:0.600867
# [147]	eval-logloss:0.600818
# [148]	eval-logloss:0.600833
# [149]	eval-logloss:0.60097
# [150]	eval-logloss:0.600959
# [151]	eval-logloss:0.600967
# [152]	eval-logloss:0.601016
# [153]	eval-logloss:0.601021
# [154]	eval-logloss:0.600938
# [155]	eval-logloss:0.600906
# [156]	eval-logloss:0.600878
# [157]	eval-logloss:0.600919
# [158]	eval-logloss:0.600919
# [159]	eval-logloss:0.600919
# [160]	eval-logloss:0.600889
# [161]	eval-logloss:0.600868
# [162]	eval-logloss:0.600838
# [163]	eval-logloss:0.600958
# [164]	eval-logloss:0.600949
# [165]	eval-logloss:0.600948
# [166]	eval-logloss:0.60096
# [167]	eval-logloss:0.600959
# [168]	eval-logloss:0.60089
# [169]	eval-logloss:0.600923
# [170]	eval-logloss:0.600995
# [171]	eval-logloss:0.600984
# [172]	eval-logloss:0.601002
# [173]	eval-logloss:0.601015
# [174]	eval-logloss:0.600981
# [175]	eval-logloss:0.600986
# [176]	eval-logloss:0.601131
# [177]	eval-logloss:0.601126
# [178]	eval-logloss:0.600939
# [179]	eval-logloss:0.601109
# [180]	eval-logloss:0.601113
# [181]	eval-logloss:0.601057
# [182]	eval-logloss:0.601122
# [183]	eval-logloss:0.60109
# [184]	eval-logloss:0.601024
# [185]	eval-logloss:0.601039
# [186]	eval-logloss:0.601165
# [187]	eval-logloss:0.601046
# [188]	eval-logloss:0.600983
# [189]	eval-logloss:0.600906
# [190]	eval-logloss:0.600995
# [191]	eval-logloss:0.60093
# [192]	eval-logloss:0.60097
# Stopping. Best iteration:
# [142]	eval-logloss:0.600546

# %%
X_dtrain, X_deval, y_dtrain, y_deval = train_test_split(train, flag, random_state=2046, test_size=0.15)
prior = 0.4
dtrain = xgb.DMatrix(X_dtrain, y_dtrain)
deval = xgb.DMatrix(X_deval, y_deval)
watchlist = [(deval, 'eval')]
params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'colsample_bytree': 0.9,
    'eta': 0.2,
    'max_depth': 3,
    'seed': 2017,
    'silent': 1,
    'gamma':0.015,
    'subsample':0.9,
     'base_score': prior,
    'eval_metric': 'logloss'
}

clf = xgb.train(params, dtrain, 200, watchlist, early_stopping_rounds=50)
# Out:
# [0]	eval-logloss:0.662168
# Will train until eval-logloss hasn't improved in 50 rounds.
# [1]	eval-logloss:0.645299
# [2]	eval-logloss:0.636414
# [3]	eval-logloss:0.62782
# [4]	eval-logloss:0.62205
# [5]	eval-logloss:0.618883
# [6]	eval-logloss:0.615244
# [7]	eval-logloss:0.612843
# [8]	eval-logloss:0.611218
# [9]	eval-logloss:0.609656
# [10]	eval-logloss:0.608756
# [11]	eval-logloss:0.60767
# [12]	eval-logloss:0.606738
# [13]	eval-logloss:0.606651
# [14]	eval-logloss:0.60606
# [15]	eval-logloss:0.605647
# [16]	eval-logloss:0.605375
# [17]	eval-logloss:0.604937
# [18]	eval-logloss:0.60459
# [19]	eval-logloss:0.604054
# [20]	eval-logloss:0.603841
# [21]	eval-logloss:0.603689
# [22]	eval-logloss:0.603587
# [23]	eval-logloss:0.603642
# [24]	eval-logloss:0.603386
# [25]	eval-logloss:0.603254
# [26]	eval-logloss:0.603345
# [27]	eval-logloss:0.603267
# [28]	eval-logloss:0.602899
# [29]	eval-logloss:0.602977
# [30]	eval-logloss:0.602766
# [31]	eval-logloss:0.602596
# [32]	eval-logloss:0.60245
# [33]	eval-logloss:0.602245
# [34]	eval-logloss:0.602218
# [35]	eval-logloss:0.602084
# [36]	eval-logloss:0.60218
# [37]	eval-logloss:0.602206
# [38]	eval-logloss:0.602063
# [39]	eval-logloss:0.602073
# [40]	eval-logloss:0.602022
# [41]	eval-logloss:0.60192
# [42]	eval-logloss:0.60184
# [43]	eval-logloss:0.602012
# [44]	eval-logloss:0.601918
# [45]	eval-logloss:0.601989
# [46]	eval-logloss:0.601914
# [47]	eval-logloss:0.601856
# [48]	eval-logloss:0.601832
# [49]	eval-logloss:0.601881
# [50]	eval-logloss:0.601836
# [51]	eval-logloss:0.602092
# [52]	eval-logloss:0.601976
# [53]	eval-logloss:0.601855
# [54]	eval-logloss:0.601729
# [55]	eval-logloss:0.601638
# [56]	eval-logloss:0.600981
# [57]	eval-logloss:0.600902
# [58]	eval-logloss:0.600922
# [59]	eval-logloss:0.600703
# [60]	eval-logloss:0.60066
# [61]	eval-logloss:0.600641
# [62]	eval-logloss:0.600565
# [63]	eval-logloss:0.600572
# [64]	eval-logloss:0.600417
# [65]	eval-logloss:0.600281
# [66]	eval-logloss:0.600236
# [67]	eval-logloss:0.599854
# [68]	eval-logloss:0.599837
# [69]	eval-logloss:0.599841
# [70]	eval-logloss:0.599908
# [71]	eval-logloss:0.599823
# [72]	eval-logloss:0.599935
# [73]	eval-logloss:0.599939
# [74]	eval-logloss:0.599897
# [75]	eval-logloss:0.599921
# [76]	eval-logloss:0.600033
# [77]	eval-logloss:0.600105
# [78]	eval-logloss:0.599996
# [79]	eval-logloss:0.599794
# [80]	eval-logloss:0.599746
# [81]	eval-logloss:0.599687
# [82]	eval-logloss:0.599762
# [83]	eval-logloss:0.599883
# [84]	eval-logloss:0.599988
# [85]	eval-logloss:0.600071
# [86]	eval-logloss:0.60006
# [87]	eval-logloss:0.600066
# [88]	eval-logloss:0.600009
# [89]	eval-logloss:0.600088
# [90]	eval-logloss:0.600089
# [91]	eval-logloss:0.600045
# [92]	eval-logloss:0.600066
# [93]	eval-logloss:0.600071
# [94]	eval-logloss:0.599979
# [95]	eval-logloss:0.599974
# [96]	eval-logloss:0.600009
# [97]	eval-logloss:0.599922
# [98]	eval-logloss:0.599985
# [99]	eval-logloss:0.600023
# [100]	eval-logloss:0.6
# [101]	eval-logloss:0.600057
# [102]	eval-logloss:0.599984
# [103]	eval-logloss:0.599987
# [104]	eval-logloss:0.600179
# [105]	eval-logloss:0.600227
# [106]	eval-logloss:0.600073
# [107]	eval-logloss:0.600075
# [108]	eval-logloss:0.600091
# [109]	eval-logloss:0.600008
# [110]	eval-logloss:0.600101
# [111]	eval-logloss:0.600043
# [112]	eval-logloss:0.600097
# [113]	eval-logloss:0.599861
# [114]	eval-logloss:0.59982
# [115]	eval-logloss:0.599884
# [116]	eval-logloss:0.600006
# [117]	eval-logloss:0.599992
# [118]	eval-logloss:0.599956
# [119]	eval-logloss:0.599866
# [120]	eval-logloss:0.599941
# [121]	eval-logloss:0.600061
# [122]	eval-logloss:0.600072
# [123]	eval-logloss:0.60006
# [124]	eval-logloss:0.599987
# [125]	eval-logloss:0.599776
# [126]	eval-logloss:0.599896
# [127]	eval-logloss:0.6
# [128]	eval-logloss:0.600017
# [129]	eval-logloss:0.599984
# [130]	eval-logloss:0.599995
# [131]	eval-logloss:0.600031
# Stopping. Best iteration:
# [81]	eval-logloss:0.599687

# %%
import numpy as np
import pandas as pd

from xgboost.sklearn import XGBClassifier
from sklearn.model_selection import train_test_split

# Load data and roughly clean it, then sort as game date
df = pd.read_csv("./data_original.csv")
df.drop(['game_event_id', 'game_id', 'lat', 'lon', 'team_id', 'team_name'], axis=1, inplace=True)
df.sort_values('game_date',  inplace=True)
mask = df['shot_made_flag'].isnull()


# Clean data
actiontypes = dict(df.action_type.value_counts())
df['type'] = df.apply(lambda row: row['action_type'] if actiontypes[row['action_type']] > 20\
                          else row['combined_shot_type'], axis=1)
df.drop(['action_type', 'combined_shot_type'], axis=1, inplace=True)

df['away'] = df.matchup.str.contains('@')
df.drop('matchup', axis=1, inplace=True)

df['distance'] = df.apply(lambda row: row['shot_distance'] if row['shot_distance'] <45 else 45, axis=1)

df['time_remaining'] = df.apply(lambda row: row['minutes_remaining'] * 60 + row['seconds_remaining'], axis=1)
df['last_moments'] = df.apply(lambda row: 1 if row['time_remaining'] < 3 else 0, axis=1)

data = pd.get_dummies(df['type'],prefix="action_type")

features=["away", "period", "playoffs", "shot_type", "shot_zone_area", "shot_zone_basic", "season",
           "shot_zone_range", "opponent", "distance", "minutes_remaining", "last_moments"]
for f in features:
    data = pd.concat([data, pd.get_dummies(df[f], prefix=f),], axis=1)

# Need work on game_date, add this into feature and increse n_estimators can inprove results but waste time and memory 

X = data[~mask]
y = df.shot_made_flag[~mask]

data=pd.read_csv("./data.csv")
data=data.dropna()
data.isna().sum()
data.to_csv("./data_cleansed.csv")

# %%
df_all=pd.read_csv('data_cleansed.csv')
df_teid=pd.read_csv('sample_submission.csv')
#split data into training and testing
test_id=df_teid['shot_id'].tolist()
#string format into datetime
df_all['game_date'] = pd.to_datetime(df_all['game_date'])
#if it is a back to back game
#(df_all['game_date'][100]-df_all['game_date'][1]).days #int
def btb(lst): #0,1
   btb_lst=[0]
   flag=0
   for i in range(1,len(lst)):
#         print("Iteration : ",i)
       if (lst[i]-lst[i-1]).days==1:
#             print (lst[i],lst[i-1])
           btb_lst.append(1)
#             print(btb_lst)
           flag=1
       elif (lst[i]-lst[i-1]).days==0:
           btb_lst.append(flag)
       else:
           flag=0
           btb_lst.append(flag)
   return btb_lst

df_all['btb']=btb(df_all['game_date'])
#home court game or not
def homecourt(row):
   if '@' in row:
       return 0
   elif 'vs' in row:
       return 1
   else:
       return 'error'



homecourt_label=df_all['matchup'].apply(homecourt)
df_all['homecourt']=homecourt_label
#game month
#w['female'] = w['female'].map({'female': 1, 'male': 0})
def gamemonth(lst):
   dict_month={'1': 'Jan', '2': 'Feb', '3': 'Mar',
               '4': 'Apr', '5': 'May', '6': 'Jun',
               '7': 'Jul', '8': 'Aug', '9': 'Sep',
               '10': 'Oct', '11': 'Nov', '12': 'Dec'}

   splitseries=lst.apply(lambda row :str(row.month))
#     print("Split : ", splitseries)

   newseries=splitseries.map(dict_month)
#     print("New : ", newseries)

   return newseries

gamemonth(df_all['game_date']).isnull().values.any() #false
df_all['gamemonth']=gamemonth(df_all['game_date'])

#if last shot was made
def lastshot(lst):
   last=[0]
   for i in range(1,len(lst)):

       if lst[i-1]==0:
           flag=0
           last.append(0)
       elif lst[i-1]==1:
           flag=1
           last.append(1)
       else:
           last.append('unknown') #due to the random test data
   return last

df_all['last_shot_flag']=lastshot(df_all['shot_made_flag'])

#add column secondsToPeriodEnd
df_all['secondsToPeriodEnd'] = 60*df_all['minutes_remaining']+df_all['seconds_remaining']
#add column secondsFromPeriodEnd
df_all['secondsFromGameStart'] = df_all['period'].astype(int)*12*60 - df_all['secondsToPeriodEnd']
criterion = df_all['shot_id'].map(lambda x: x not in test_id)
criterion1 = df_all['shot_id'].map(lambda x: x in test_id)
df_all_tr=df_all[criterion]
df_all_te=df_all[criterion1]

ctg_feature=['combined_shot_type',
            'shot_id','shot_type',
            'action_type',
            'shot_zone_area', 'shot_zone_basic', 'playoffs', 'period','opponent','season',
            'homecourt',
            'btb',
            'gamemonth',
           'last_shot_flag'
            ]
num_feature=['loc_x', 'loc_y', 'shot_distance','shot_id','seconds_remaining',
            'secondsToPeriodEnd','secondsFromGameStart']
df_ctg = df_all.loc[:, lambda df: ctg_feature]
encoded_ctg=pd.get_dummies(df_ctg).astype(np.int16)
criterion01 = encoded_ctg['shot_id'].map(lambda x: x not in test_id)
criterion11 = encoded_ctg['shot_id'].map(lambda x: x in test_id)


df_tr_ctg=encoded_ctg[criterion01]
df_te_ctg=encoded_ctg[criterion11]
df_tr_num = df_all_tr.loc[:, lambda df: num_feature]
df_te_num = df_all_te.loc[:, lambda df: num_feature]
flag = df_all_tr['shot_made_flag']

train=pd.merge(df_tr_ctg, df_tr_num,on='shot_id')

test=pd.merge(df_te_ctg, df_te_num,on='shot_id')

# %%
X_dtrain, X_deval, y_dtrain, y_deval = train_test_split(train, flag, random_state=2046, test_size=0.15)
prior = 0.4
dtrain = xgb.DMatrix(X_dtrain, y_dtrain)
deval = xgb.DMatrix(X_deval, y_deval)
watchlist = [(deval, 'eval')]
params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'colsample_bytree': 0.5,
    'eta': 0.2,
    'max_depth': 4,
    'seed': 2017,
    'silent': 1,
    'gamma':0.015,
    'subsample':0.8,
    'base_score': prior,
    'eval_metric': 'logloss'
}

clf = xgb.train(params, dtrain, 200, watchlist, early_stopping_rounds=50)
# Out:
# [0]	eval-logloss:0.66742
# Will train until eval-logloss hasn't improved in 50 rounds.
# [1]	eval-logloss:0.659651
# [2]	eval-logloss:0.645395
# [3]	eval-logloss:0.641312
# [4]	eval-logloss:0.635655
# [5]	eval-logloss:0.62645
# [6]	eval-logloss:0.620409
# [7]	eval-logloss:0.616209
# [8]	eval-logloss:0.612721
# [9]	eval-logloss:0.610872
# [10]	eval-logloss:0.610431
# [11]	eval-logloss:0.609264
# [12]	eval-logloss:0.608606
# [13]	eval-logloss:0.606431
# [14]	eval-logloss:0.605653
# [15]	eval-logloss:0.605369
# [16]	eval-logloss:0.604645
# [17]	eval-logloss:0.603508
# [18]	eval-logloss:0.60348
# [19]	eval-logloss:0.603232
# [20]	eval-logloss:0.602913
# [21]	eval-logloss:0.602664
# [22]	eval-logloss:0.602721
# [23]	eval-logloss:0.602603
# [24]	eval-logloss:0.602507
# [25]	eval-logloss:0.60247
# [26]	eval-logloss:0.602304
# [27]	eval-logloss:0.60244
# [28]	eval-logloss:0.602286
# [29]	eval-logloss:0.601626
# [30]	eval-logloss:0.601593
# [31]	eval-logloss:0.60164
# [32]	eval-logloss:0.601217
# [33]	eval-logloss:0.600534
# [34]	eval-logloss:0.600358
# [35]	eval-logloss:0.600061
# [36]	eval-logloss:0.599973
# [37]	eval-logloss:0.599819
# [38]	eval-logloss:0.599793
# [39]	eval-logloss:0.599559
# [40]	eval-logloss:0.599509
# [41]	eval-logloss:0.599685
# [42]	eval-logloss:0.599398
# [43]	eval-logloss:0.5993
# [44]	eval-logloss:0.599399
# [45]	eval-logloss:0.599325
# [46]	eval-logloss:0.599244
# [47]	eval-logloss:0.59909
# [48]	eval-logloss:0.598792
# [49]	eval-logloss:0.598798
# [50]	eval-logloss:0.598893
# [51]	eval-logloss:0.598779
# [52]	eval-logloss:0.598781
# [53]	eval-logloss:0.598555
# [54]	eval-logloss:0.598506
# [55]	eval-logloss:0.598846
# [56]	eval-logloss:0.598602
# [57]	eval-logloss:0.598755
# [58]	eval-logloss:0.598963
# [59]	eval-logloss:0.598831
# [60]	eval-logloss:0.59894
# [61]	eval-logloss:0.598919
# [62]	eval-logloss:0.598967
# [63]	eval-logloss:0.599029
# [64]	eval-logloss:0.59905
# [65]	eval-logloss:0.599363
# [66]	eval-logloss:0.599814
# [67]	eval-logloss:0.599622
# [68]	eval-logloss:0.599443
# [69]	eval-logloss:0.599213
# [70]	eval-logloss:0.599279
# [71]	eval-logloss:0.599423
# [72]	eval-logloss:0.599274
# [73]	eval-logloss:0.599473
# [74]	eval-logloss:0.599551
# [75]	eval-logloss:0.599541
# [76]	eval-logloss:0.59946
# [77]	eval-logloss:0.599413
# [78]	eval-logloss:0.599538
# [79]	eval-logloss:0.599385
# [80]	eval-logloss:0.599727
# [81]	eval-logloss:0.59981
# [82]	eval-logloss:0.599957
# [83]	eval-logloss:0.599966
# [84]	eval-logloss:0.599832
# [85]	eval-logloss:0.599601
# [86]	eval-logloss:0.599583
# [87]	eval-logloss:0.599779
# [88]	eval-logloss:0.599826
# [89]	eval-logloss:0.599902
# [90]	eval-logloss:0.599926
# [91]	eval-logloss:0.600044
# [92]	eval-logloss:0.600165
# [93]	eval-logloss:0.600125
# [94]	eval-logloss:0.600272
# [95]	eval-logloss:0.600257
# [96]	eval-logloss:0.600163
# [97]	eval-logloss:0.600129
# [98]	eval-logloss:0.600054
# [99]	eval-logloss:0.600609
# [100]	eval-logloss:0.600546
# [101]	eval-logloss:0.600566
# [102]	eval-logloss:0.60048
# [103]	eval-logloss:0.600818
# [104]	eval-logloss:0.600975
# Stopping. Best iteration:
# [54]	eval-logloss:0.598506
